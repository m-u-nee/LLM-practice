# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
#device = torch.device('mps')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)


with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6568, val loss 2.6670
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mattia/Desktop/zero_to_hero/test.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=202'>203</a> xb, yb = get_batch('train')
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=204'>205</a> # evaluate the loss
# --> <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=205'>206</a> logits, loss = model(xb, yb)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=206'>207</a> optimizer.zero_grad(set_to_none=True)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=207'>208</a> loss.backward()
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# /Users/mattia/Desktop/zero_to_hero/test.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=153'>154</a> pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=154'>155</a> x = tok_emb + pos_emb # (B,T,C)
# --> <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=155'>156</a> x = self.blocks(x) # (B,T,C)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=156'>157</a> x = self.ln_f(x) # (B,T,C)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=157'>158</a> logits = self.lm_head(x) # (B,T,vocab_size)
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# /Users/mattia/Desktop/zero_to_hero/test.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=131'>132</a> def forward(self, x):
# --> <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=132'>133</a>     x = x + self.sa(self.ln1(x))
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=133'>134</a>     x = x + self.ffwd(self.ln2(x))
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=134'>135</a>     return x
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# /Users/mattia/Desktop/zero_to_hero/test.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=99'>100</a> def forward(self, x):
# --> <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=100'>101</a>     out = torch.cat([h(x) for h in self.heads], dim=-1)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=101'>102</a>     out = self.dropout(self.proj(out))
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=102'>103</a>     return out
#
# /Users/mattia/Desktop/zero_to_hero/test.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=99'>100</a> def forward(self, x):
# --> <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=100'>101</a>     out = torch.cat([h(x) for h in self.heads], dim=-1)
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=101'>102</a>     out = self.dropout(self.proj(out))
#     <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=102'>103</a>     return out
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# /Users/mattia/Desktop/zero_to_hero/test.ipynb Cell 1 line 8
#      <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=81'>82</a> wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
#      <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=82'>83</a> wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
# ---> <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=83'>84</a> wei = F.softmax(wei, dim=-1) # (B, T, T)
#      <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=84'>85</a> wei = self.dropout(wei)
#      <a href='vscode-notebook-cell:/Users/mattia/Desktop/zero_to_hero/test.ipynb#W0sZmlsZQ%3D%3D?line=85'>86</a> # perform the weighted aggregation of the values
#
# File ~/miniconda3/envs/general_ml/lib/python3.11/site-packages/torch/nn/functional.py:1826, in softmax(input, dim, _stacklevel, dtype)
#    1822         ret = (-input).softmax(dim, dtype=dtype)
#    1823     return ret
# -> 1826 def softmax(input: Tensor, dim: Optional[int] = None, _stacklevel: int = 3, dtype: Optional[DType] = None) -> Tensor:
#    1827     r"""Applies a softmax function.
#    1828
#    1829     Softmax is defined as:
#    (...)
#    1849
#    1850     """
#    1851     if has_torch_function_unary(input):
#
# KeyboardInterrupt:

# %%
max_iters = 20000
for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# step 0: train loss 1.4477, val loss 1.6563
# step 100: train loss 1.4292, val loss 1.6733
# step 200: train loss 1.4427, val loss 1.6645
# step 300: train loss 1.4357, val loss 1.6540
# step 400: train loss 1.4433, val loss 1.6752
# step 500: train loss 1.4433, val loss 1.6623
# step 600: train loss 1.4555, val loss 1.6506
# step 700: train loss 1.4432, val loss 1.6665
# step 800: train loss 1.4449, val loss 1.6683
# step 900: train loss 1.4393, val loss 1.6579
# step 1000: train loss 1.4427, val loss 1.6598
# step 1100: train loss 1.4428, val loss 1.6675
# step 1200: train loss 1.4389, val loss 1.6538
# step 1300: train loss 1.4331, val loss 1.6424
# step 1400: train loss 1.4436, val loss 1.6574
# step 1500: train loss 1.4510, val loss 1.6556
# step 1600: train loss 1.4385, val loss 1.6525
# step 1700: train loss 1.4357, val loss 1.6611
# step 1800: train loss 1.4393, val loss 1.6520
# step 1900: train loss 1.4427, val loss 1.6463
# step 2000: train loss 1.4408, val loss 1.6505
# step 2100: train loss 1.4313, val loss 1.6613
# step 2200: train loss 1.4413, val loss 1.6516
# step 2300: train loss 1.4377, val loss 1.6585
# step 2400: train loss 1.4387, val loss 1.6582
# step 2500: train loss 1.4360, val loss 1.6509
# step 2600: train loss 1.4368, val loss 1.6597
# step 2700: train loss 1.4427, val loss 1.6588
# step 2800: train loss 1.4400, val loss 1.6494
# step 2900: train loss 1.4284, val loss 1.6596
# step 3000: train loss 1.4478, val loss 1.6494
# step 3100: train loss 1.4339, val loss 1.6474
# step 3200: train loss 1.4376, val loss 1.6518
# step 3300: train loss 1.4443, val loss 1.6631
# step 3400: train loss 1.4304, val loss 1.6599
# step 3500: train loss 1.4362, val loss 1.6565
# step 3600: train loss 1.4381, val loss 1.6487
# step 3700: train loss 1.4376, val loss 1.6432
# step 3800: train loss 1.4384, val loss 1.6520
# step 3900: train loss 1.4464, val loss 1.6571
# step 4000: train loss 1.4336, val loss 1.6406
# step 4100: train loss 1.4315, val loss 1.6522
# step 4200: train loss 1.4368, val loss 1.6516
# step 4300: train loss 1.4227, val loss 1.6632
# step 4400: train loss 1.4372, val loss 1.6353
# step 4500: train loss 1.4290, val loss 1.6499
# step 4600: train loss 1.4407, val loss 1.6321
# step 4700: train loss 1.4387, val loss 1.6489
# step 4800: train loss 1.4308, val loss 1.6541
# step 4900: train loss 1.4451, val loss 1.6442
# step 5000: train loss 1.4400, val loss 1.6482
# step 5100: train loss 1.4332, val loss 1.6524
# step 5200: train loss 1.4377, val loss 1.6530
# step 5300: train loss 1.4398, val loss 1.6453
# step 5400: train loss 1.4343, val loss 1.6491
# step 5500: train loss 1.4363, val loss 1.6478
# step 5600: train loss 1.4243, val loss 1.6535
# step 5700: train loss 1.4318, val loss 1.6619
# step 5800: train loss 1.4423, val loss 1.6375
# step 5900: train loss 1.4279, val loss 1.6413
# step 6000: train loss 1.4377, val loss 1.6375
# step 6100: train loss 1.4329, val loss 1.6379
# step 6200: train loss 1.4419, val loss 1.6452
# step 6300: train loss 1.4298, val loss 1.6477
# step 6400: train loss 1.4352, val loss 1.6351
# step 6500: train loss 1.4274, val loss 1.6411
# step 6600: train loss 1.4402, val loss 1.6378
# step 6700: train loss 1.4286, val loss 1.6458
# step 6800: train loss 1.4354, val loss 1.6487
# step 6900: train loss 1.4292, val loss 1.6541
# step 7000: train loss 1.4355, val loss 1.6625
# step 7100: train loss 1.4432, val loss 1.6599
# step 7200: train loss 1.4315, val loss 1.6471
# step 7300: train loss 1.4310, val loss 1.6472
# step 7400: train loss 1.4355, val loss 1.6432
# step 7500: train loss 1.4291, val loss 1.6491
# step 7600: train loss 1.4162, val loss 1.6549
# step 7700: train loss 1.4387, val loss 1.6567
# step 7800: train loss 1.4274, val loss 1.6510
# step 7900: train loss 1.4289, val loss 1.6555
# step 8000: train loss 1.4334, val loss 1.6452
# step 8100: train loss 1.4284, val loss 1.6681
# step 8200: train loss 1.4334, val loss 1.6410
# step 8300: train loss 1.4290, val loss 1.6469
# step 8400: train loss 1.4193, val loss 1.6421
# step 8500: train loss 1.4326, val loss 1.6495
# step 8600: train loss 1.4350, val loss 1.6412
# step 8700: train loss 1.4322, val loss 1.6489
# step 8800: train loss 1.4345, val loss 1.6504
# step 8900: train loss 1.4259, val loss 1.6443
# step 9000: train loss 1.4263, val loss 1.6479
# step 9100: train loss 1.4196, val loss 1.6365
# step 9200: train loss 1.4191, val loss 1.6487
# step 9300: train loss 1.4289, val loss 1.6528
# step 9400: train loss 1.4267, val loss 1.6447
# step 9500: train loss 1.4242, val loss 1.6677
# step 9600: train loss 1.4269, val loss 1.6503
# step 9700: train loss 1.4245, val loss 1.6445
# step 9800: train loss 1.4346, val loss 1.6346
# step 9900: train loss 1.4288, val loss 1.6503
# step 10000: train loss 1.4300, val loss 1.6430
# step 10100: train loss 1.4337, val loss 1.6494
# step 10200: train loss 1.4346, val loss 1.6507
# step 10300: train loss 1.4374, val loss 1.6458
# step 10400: train loss 1.4203, val loss 1.6426
# step 10500: train loss 1.4266, val loss 1.6420
# step 10600: train loss 1.4333, val loss 1.6528
# step 10700: train loss 1.4224, val loss 1.6468
# step 10800: train loss 1.4317, val loss 1.6381
# step 10900: train loss 1.4256, val loss 1.6466
# step 11000: train loss 1.4254, val loss 1.6432
# step 11100: train loss 1.4370, val loss 1.6488
# step 11200: train loss 1.4183, val loss 1.6469
# step 11300: train loss 1.4308, val loss 1.6481
# step 11400: train loss 1.4251, val loss 1.6429
# step 11500: train loss 1.4277, val loss 1.6532
# step 11600: train loss 1.4177, val loss 1.6491
# step 11700: train loss 1.4290, val loss 1.6344
# step 11800: train loss 1.4262, val loss 1.6570
# step 11900: train loss 1.4306, val loss 1.6492
# step 12000: train loss 1.4198, val loss 1.6363
# step 12100: train loss 1.4220, val loss 1.6498
# step 12200: train loss 1.4164, val loss 1.6371
# step 12300: train loss 1.4279, val loss 1.6417
# step 12400: train loss 1.4325, val loss 1.6429
# step 12500: train loss 1.4234, val loss 1.6502
# step 12600: train loss 1.4234, val loss 1.6334
# step 12700: train loss 1.4245, val loss 1.6388
# step 12800: train loss 1.4278, val loss 1.6559
# step 12900: train loss 1.4145, val loss 1.6521
# step 13000: train loss 1.4164, val loss 1.6507
# step 13100: train loss 1.4210, val loss 1.6384
# step 13200: train loss 1.4333, val loss 1.6522
# step 13300: train loss 1.4219, val loss 1.6300
# step 13400: train loss 1.4283, val loss 1.6294
# step 13500: train loss 1.4131, val loss 1.6465
# step 13600: train loss 1.4226, val loss 1.6369
# step 13700: train loss 1.4242, val loss 1.6495
# step 13800: train loss 1.4185, val loss 1.6436
# step 13900: train loss 1.4289, val loss 1.6381
# step 14000: train loss 1.4161, val loss 1.6413
# step 14100: train loss 1.4173, val loss 1.6472
# step 14200: train loss 1.4180, val loss 1.6518
# step 14300: train loss 1.4111, val loss 1.6430
# step 14400: train loss 1.4162, val loss 1.6313
# step 14500: train loss 1.4179, val loss 1.6493
# step 14600: train loss 1.4202, val loss 1.6474
# step 14700: train loss 1.4183, val loss 1.6397
# step 14800: train loss 1.4303, val loss 1.6585
# step 14900: train loss 1.4110, val loss 1.6352
# step 15000: train loss 1.4284, val loss 1.6593
# step 15100: train loss 1.4255, val loss 1.6477
# step 15200: train loss 1.4136, val loss 1.6382
# step 15300: train loss 1.4201, val loss 1.6466
# step 15400: train loss 1.4244, val loss 1.6360
# step 15500: train loss 1.4175, val loss 1.6404
# step 15600: train loss 1.4161, val loss 1.6333
# step 15700: train loss 1.4255, val loss 1.6544
# step 15800: train loss 1.4150, val loss 1.6471
# step 15900: train loss 1.4346, val loss 1.6509
# step 16000: train loss 1.4167, val loss 1.6448
# step 16100: train loss 1.4177, val loss 1.6414
# step 16200: train loss 1.4200, val loss 1.6522
# step 16300: train loss 1.4227, val loss 1.6524
# step 16400: train loss 1.4176, val loss 1.6358
# step 16500: train loss 1.4189, val loss 1.6334
# step 16600: train loss 1.4140, val loss 1.6394
# step 16700: train loss 1.4153, val loss 1.6493
# step 16800: train loss 1.4068, val loss 1.6333
# step 16900: train loss 1.4142, val loss 1.6449
# step 17000: train loss 1.4164, val loss 1.6359
# step 17100: train loss 1.4287, val loss 1.6337
# step 17200: train loss 1.4156, val loss 1.6386
# step 17300: train loss 1.4161, val loss 1.6279
# step 17400: train loss 1.4201, val loss 1.6509
# step 17500: train loss 1.4161, val loss 1.6414
# step 17600: train loss 1.4206, val loss 1.6341
# step 17700: train loss 1.4160, val loss 1.6476
# step 17800: train loss 1.4107, val loss 1.6422
# step 17900: train loss 1.4148, val loss 1.6464
# step 18000: train loss 1.4161, val loss 1.6413
# step 18100: train loss 1.4198, val loss 1.6251
# step 18200: train loss 1.4160, val loss 1.6385
# step 18300: train loss 1.4074, val loss 1.6604
# step 18400: train loss 1.4180, val loss 1.6430
# step 18500: train loss 1.4144, val loss 1.6436
# step 18600: train loss 1.4104, val loss 1.6383
# step 18700: train loss 1.4088, val loss 1.6406
# step 18800: train loss 1.4145, val loss 1.6525
# step 18900: train loss 1.4143, val loss 1.6377
# step 19000: train loss 1.4182, val loss 1.6341
# step 19100: train loss 1.4127, val loss 1.6319
# step 19200: train loss 1.4156, val loss 1.6444
# step 19300: train loss 1.4174, val loss 1.6435
# step 19400: train loss 1.4135, val loss 1.6361
# step 19500: train loss 1.4163, val loss 1.6434
# step 19600: train loss 1.4154, val loss 1.6262
# step 19700: train loss 1.4139, val loss 1.6292
# step 19800: train loss 1.4125, val loss 1.6407
# step 19900: train loss 1.4215, val loss 1.6379
# step 19999: train loss 1.4154, val loss 1.6314
#
# Beter miscourfortunate with them
# And day, store Hereford's against
# With Hesolt, come in that our chidward and in the city man: take me the dumatress
# With suptly with of Bolingbroke out; no allows:
# A pirate infut it in. Saint Care your good wast.
#
# KING RICHARD IIII:
# Here now! we procle, I think the word.
#
# MARCIUS:
# You madalic, do, or soar thou
# in thy person lock and unnapate:
# If thy fair, gentlemen: which I saw, all
# To-day these thou soored to purse incour.
# Now sturn to me thy lord.
#
# MENENIUS:
# You at arm it not man's.
#
# even:
# Come your vership with accurious
# To bid heaven image; he made speed too. Fitzwatt, Come hither body upon your leging cloachs!
# Thyselfher's childness, and
# earth wast his luckle!
# O sons 'alth at head upon thy siestrest come upon't: here proper Citizen is in this bosom Lucing what's God to rust,
# Speak and him his bettershing ruler.
#
# GRUMIO:
# No, mething me: that rar you come at one well repent of this absage
# And out.
#
# First Kent:
# Sea shrew roil jest your reasony:
# Swear thy reture of this much; which it,
# His blitter sword of her town; with marries Burgage;
# Madam, if it will know
# Thy wind to all my patience.
#
# KING RICHARD III:
# That will said in the world of the charge; mean at Aufiator.
#
# GRUMIO:
# Well shall be for him, condemning:
# I would hear you the heart? tells I got give us, sode abroes more must wrecks,
# Be tomorrow impate, which makes for rise
# I cause
# And with oother waking; an I achelf toste now; good
# pay the offence head he mad? you would, up a subtle condemning, and in the score of angerous Ragozingh us.
#
# LRIAD:
# Nay, did for to die.
#
# VALERIA:
# Either, but you are all that neither,
# Which burden all balt him. Lord of Citizens the anger-hate, and what eyou at that to
# Will journey.
#
# JULIV:
# King Hasting of he be Edward unapon,
# Let a king. Lew, time his polish'd; and by the noble, too much, poor mars
# To me to-the bottom interjey. Hoth, choing is reume king
# My mark? I know my son: low if goes too pain that am it in deserved, said!
# Soes that room threats

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# Be Duke of York, if I having.
#
# QUEEN:
#
# Third Citizen:
# or good Gaunt men thou be'rd, and forth thee,
# Claud I have ning
# Stil Yo: such stervy and
# jotion be buid'd, if tears merny peacer.
#
# EDWARD:
# This is not bear that if fear.
#
# PRINCE EDWARD:
# Could stay, I did thy rear, sir, and make action.
#
# KING RICHARD III:
# Repeal: thy shapes, which is
# With keepping-death: yet way--
# I beseem yet go in this law; and for never comes itself.
#
# FRIAR LAURE, so.
#
# EDWARD:
# A flight of those eye, in my death!
# Thou wives for the Duffed to cheek.
#
# Second Mercutio, in?
#
# GLOUCESTER:
# Ah, time my bear tedious lists infeignt of Gaunt
# From such a, and with us.
#
# MENENIUS:
# Yea, Eieven, Sir! sir, 'twas?
#
# DUKE VINCENTIO:
# I'll rest in
# Anchor would, therefore
# Grey, duke in their life.
#
# Third Servingman:
# My brother persour to the traitors.
#
# Nurse:
# For more things. How long hath, as thou fear
# Will too apence of the requet, that to pain satial pins that sweet?
#
# MERCUTIO:
# Else, Claud, ruinds hood bettom thy lord.
#
#
# DUCHESS OF YORK:
# You city, another heaven. York.
#
# Ho busines: I precious gwife percutio's
# Reman as indeed providet and her,
# Help send a grace would being her limb asides
# and, is it some does do to me. My majesty compony. How!
# Thou, mird is not determ.
# Is any houses, Bolingbroke, if this nobles,
# And be the sons shalt killy you know my joy,
# That Cire you art banished me, therewith myself with that
# into our repent and him: but wife Aufidium shame that sunders,
# With last spread of the anvice o'er-bearn'd, may gently ching up my away:
# They are no thing.
#
# KING RICHARD IIII:
# Hath some invictuet.
#
# CAMILLO:
# What Cain Carlifit what is this compate him rest stir:
# There record, you shall bid these of unnity.
#
# KING RICHARD IIII:
# His chargent of that I have a manny!
#
# PLIFFORD:
# Go thou shalt not to Mowbray,
# To fooling thou set my sweet blay,
# Be this night blood's tauntic more
# And rather endry of the call is the wife.
#
# Solent.
# If the royal foot of it; and thou art violently Heldry Geought thy bird of thee.
#
# Rock,
