# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 64 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
#device = torch.device('mps')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 8
n_layer = 8
dropout = 0.0
# ------------



with open('commedia.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
# Out:
# 0.4103 M parameters

# %%
max_iters = 10000
for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    
    optimizer.step()
# Out:
# step 0: train loss 4.2201, val loss 4.2182
# step 100: train loss 2.4424, val loss 2.4667
# step 200: train loss 2.3575, val loss 2.3880
# step 300: train loss 2.2965, val loss 2.3252
# step 400: train loss 2.2522, val loss 2.2777
# step 500: train loss 2.2043, val loss 2.2348
# step 600: train loss 2.1531, val loss 2.1839
# step 700: train loss 2.0795, val loss 2.1150
# step 800: train loss 2.0263, val loss 2.0492
# step 900: train loss 1.9756, val loss 2.0120
# step 1000: train loss 1.9373, val loss 1.9683
# step 1100: train loss 1.9217, val loss 1.9603
# step 1200: train loss 1.8850, val loss 1.9327
# step 1300: train loss 1.8533, val loss 1.9060
# step 1400: train loss 1.8398, val loss 1.8910
# step 1500: train loss 1.8157, val loss 1.8673
# step 1600: train loss 1.7844, val loss 1.8408
# step 1700: train loss 1.7683, val loss 1.8279
# step 1800: train loss 1.7588, val loss 1.8192
# step 1900: train loss 1.7304, val loss 1.7968
# step 2000: train loss 1.7208, val loss 1.7886
# step 2100: train loss 1.6928, val loss 1.7679
# step 2200: train loss 1.6840, val loss 1.7801
# step 2300: train loss 1.6761, val loss 1.7513
# step 2400: train loss 1.6572, val loss 1.7441
# step 2500: train loss 1.6332, val loss 1.7382
# step 2600: train loss 1.6242, val loss 1.7248
# step 2700: train loss 1.6163, val loss 1.7199
# step 2800: train loss 1.6114, val loss 1.7160
# step 2900: train loss 1.5907, val loss 1.7116
# step 3000: train loss 1.5872, val loss 1.6996
# step 3100: train loss 1.5678, val loss 1.7074
# step 3200: train loss 1.5676, val loss 1.6958
# step 3300: train loss 1.5480, val loss 1.6925
# step 3400: train loss 1.5451, val loss 1.6982
# step 3500: train loss 1.5348, val loss 1.6866
# step 3600: train loss 1.5202, val loss 1.6840
# step 3700: train loss 1.5268, val loss 1.6794
# step 3800: train loss 1.5019, val loss 1.6702
# step 3900: train loss 1.4922, val loss 1.6809
# step 4000: train loss 1.4898, val loss 1.6653
# step 4100: train loss 1.4849, val loss 1.6874
# step 4200: train loss 1.4719, val loss 1.6807
# step 4300: train loss 1.4614, val loss 1.6674
# step 4400: train loss 1.4564, val loss 1.6747
# step 4500: train loss 1.4439, val loss 1.6654
# step 4600: train loss 1.4409, val loss 1.6686
# step 4700: train loss 1.4388, val loss 1.6884
# step 4800: train loss 1.4333, val loss 1.6844
# step 4900: train loss 1.4138, val loss 1.6720
# step 5000: train loss 1.4167, val loss 1.6827
# step 5100: train loss 1.3987, val loss 1.6655
# step 5200: train loss 1.3963, val loss 1.6789
# step 5300: train loss 1.3972, val loss 1.6761
# step 5400: train loss 1.3826, val loss 1.6780
# step 5500: train loss 1.3770, val loss 1.6752
# step 5600: train loss 1.3760, val loss 1.6919
# step 5700: train loss 1.3614, val loss 1.6681
# step 5800: train loss 1.3668, val loss 1.6906
# step 5900: train loss 1.3629, val loss 1.6894
# step 6000: train loss 1.3469, val loss 1.6819
# step 6100: train loss 1.3449, val loss 1.6887
# step 6200: train loss 1.3361, val loss 1.6941
# step 6300: train loss 1.3276, val loss 1.6934
# step 6400: train loss 1.3280, val loss 1.6967
# step 6500: train loss 1.3259, val loss 1.7122
# step 6600: train loss 1.3180, val loss 1.7058
# step 6700: train loss 1.3045, val loss 1.7114
# step 6800: train loss 1.2942, val loss 1.7101
# step 6900: train loss 1.2885, val loss 1.7123
# step 7000: train loss 1.2843, val loss 1.7175
# step 7100: train loss 1.2800, val loss 1.7092
# step 7200: train loss 1.2787, val loss 1.7310
# step 7300: train loss 1.2675, val loss 1.7265
# step 7400: train loss 1.2619, val loss 1.7270
# step 7500: train loss 1.2542, val loss 1.7240
# step 7600: train loss 1.2620, val loss 1.7478
# step 7700: train loss 1.2625, val loss 1.7426
# step 7800: train loss 1.2462, val loss 1.7530
# step 7900: train loss 1.2414, val loss 1.7589
# step 8000: train loss 1.2321, val loss 1.7475
# step 8100: train loss 1.2332, val loss 1.7464
# step 8200: train loss 1.2226, val loss 1.7770
# step 8300: train loss 1.2200, val loss 1.7764
# step 8400: train loss 1.2135, val loss 1.7620
# step 8500: train loss 1.2081, val loss 1.7702
# step 8600: train loss 1.1960, val loss 1.7861
# step 8700: train loss 1.1935, val loss 1.7835
# step 8800: train loss 1.2028, val loss 1.7976
# step 8900: train loss 1.1946, val loss 1.7715
# step 9000: train loss 1.1835, val loss 1.7812
# step 9100: train loss 1.1738, val loss 1.8149
# step 9200: train loss 1.1754, val loss 1.8108
# step 9300: train loss 1.1680, val loss 1.8139
# step 9400: train loss 1.1649, val loss 1.8230
# step 9500: train loss 1.1675, val loss 1.8330
# step 9600: train loss 1.1524, val loss 1.8252
# step 9700: train loss 1.1518, val loss 1.8532
# step 9800: train loss 1.1466, val loss 1.8228
# step 9900: train loss 1.1450, val loss 1.8350
# step 9999: train loss 1.1398, val loss 1.8542

# %%
# step 4999: train loss 1.4238, val loss 1.6874

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# Ape lor che 'l dito intene,
# quatto come ti de lo scuoro igurto.
#
# Altr' era la ettro: "Qui caddi rotto;
# dissier, che poi lasso!
#
# Quivi veder da discondesi ne mali,
# a cui paroi in giu`, com' esser 'l pozzo roppo da questa
# che mei tre vestil rieder quel si discese,
# con li animauria cui piu` per li passi.
#
# E caddi coro attene l'occhio e certo fui
# e con era proda e piu` si parenti
# dal ciele inghiea parlar piu` provi
# che la mortagnar l'emedesse legge,
# che me ne la vener ciastrato mai cose
# disser: "Maltra a Flegioooreta,
# che posciëa la mi scende cio` viso viso,
# caduto se non odo il passio guidizio,
# guardando a lui, arrito voi sofolersi
# perduto", mi  disse: "Dun poco sen l'hso mise;
#
#
# cassita e la rofama in suso la streggia
# sono udici conoscener dolorse faci
# mondo persona che 'l foco il leggo per li grazi,
# si` come via co' si` a cui
# con quella cui vento ambo l'ombra molte
# o di lor castella come l'erta e dee.
#
# Maggior chiedi ogne parte aggrapo,
# e guarda e fra di Tebera smuta:
#
# ne l'uncide sidera con la sua faccia
# che 'nvilan cosi` ode noi: "Son mi Giudo;
# Ris' anchettando, passo, vidi raggio,
# dinanzi a li occhi sonno pungi si pento,
# il cadea lor ch'i' ti conoscortamme uoggna.
#
# Amoli, ch'a dir guarda di futur di sommerse.
#
# Il vedi lui qual che ''l femmo in su l'amore.
#
# Dinanzi a me non fuor del regide espresse
# al loco dolor ch'i' v'ha t'alerani.
#
# Pur ento rassolvestro con mano,
# che non piu` m'ha accerbe l'un gual sove.
#
# Quant' e` Dio discendo la proda colta
# principio e torno, "a cui 'l terco per acquisi
# facerone in voi.
#
# La ripigliassima cov' io discese!
# E voi che per notavar la pela,
# come 'l sentibia de' Ver' un'oncinale;
# ma io m'adarara e querse cannea uscia.
#
# Piaccia e con l'altro com' adunzo, e possuto
# non ficcar, calla laditando la coste,
# porsiti porti aver, tra li eran portari.
#
# Ma chi suse: "Questi e` Colpa: i figlia
# come Bruggie cottesti danno".
#
# Si` trovammo intorpocre del monto
# forse vintan del gir torribemo more
# non par si` verbo, ne' dubiscio fui;
#
# e disse: "Bene
